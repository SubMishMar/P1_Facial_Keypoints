# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

# Check if GPU is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

# Instantiate the network and move it to the device (GPU or CPU)
net = Net()
net.to(device)
print(net)
# Out:
# Using device: cuda
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.4, inplace=False)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 16

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image'].to(device)
        key_pts = sample['keypoints'].to(device)

        # convert images to FloatTensors
        images = images.to(device, dtype=torch.float)
        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 3
#       1 # call the above function
#       2 # returns: test images, test predicted keypoints, test ground truth keypoints
# ----> 3 test_images, test_outputs, gt_pts = net_sample_output()
#       5 # print out the dimensions of the data to see if they make sense
#       6 print(test_images.data.size())
#
# Cell In[152], line 15, in net_sample_output()
#      13 images = images.to(device, dtype=torch.float)
#      14 # forward pass to get net output
# ---> 15 output_pts = net(images)
#      17 # reshape to batch_size x 68 x 2 pts
#      18 output_pts = output_pts.view(output_pts.size()[0], 68, -1)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/projects/P1_Facial_Keypoints/models.py:50, in Net.forward(self, x)
#      46 x = self.pool(F.relu(self.bn3(self.conv3(x))))
#      48 x = x.view(x.size(0), -1)  # Flatten
# ---> 50 x = F.relu(self.fc1(x))
#      51 x = self.dropout(x)
#      52 x = self.fc2(x)
#
# TypeError: 'NoneType' object is not callable

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted and ground truth keypoints."""
    plt.imshow(image, cmap='gray')

    # Ensure predicted keypoints are on CPU and converted to NumPy
    if predicted_key_pts is not None:
        if isinstance(predicted_key_pts, torch.Tensor):
            predicted_key_pts = predicted_key_pts.cpu().detach().numpy()
        plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='r')

    # Ensure ground truth keypoints are on CPU and converted to NumPy
    if gt_pts is not None:
        if isinstance(gt_pts, torch.Tensor):
            gt_pts = gt_pts.cpu().detach().numpy()
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

    plt.axis('off')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)
        
        # un-transform the image data
        image = test_images[i].data   # get the image from it's Variable wrapper
        image = image.cpu()
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.cpu()
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](https://pytorch.org/docs/master/nn.html#loss-functions).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs):
    net.train()  # Set the model to training mode
    train_losses = []

    for epoch in range(n_epochs):
        running_loss = 0.0

        # Training phase
        for batch_i, data in enumerate(train_loader):
            images = data['image']
            key_pts = data['keypoints']

            # Flatten keypoints
            key_pts = key_pts.view(key_pts.size(0), -1)

            # Move to device and convert to float
            key_pts = key_pts.to(device).float()
            images = images.to(device).float()

            # Forward pass
            output_pts = net(images)
            loss = criterion(output_pts, key_pts)

            # Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track training loss
            running_loss += loss.item()

            # Log every 10 batches
            if batch_i % 10 == 9:
                avg_train_loss = running_loss / 10
                train_losses.append(avg_train_loss)
                running_loss = 0.0
                print(f"Epoch [{epoch+1}/{n_epochs}] | Batch {batch_i+1} | Train Loss: {avg_train_loss:.4f}")
    
    print("Training Complete!")
    return train_losses

# %%
# train your network
n_epochs = 10
training_losses = train_net(n_epochs)
# Out:
# Epoch [1/30] | Batch 10 | Train Loss: 0.1491
# Epoch [1/30] | Batch 20 | Train Loss: 0.1138
# Epoch [1/30] | Batch 30 | Train Loss: 0.1084
# Epoch [1/30] | Batch 40 | Train Loss: 0.1106
# Epoch [1/30] | Batch 50 | Train Loss: 0.0947
# Epoch [1/30] | Batch 60 | Train Loss: 0.0947
# Epoch [1/30] | Batch 70 | Train Loss: 0.0914
# Epoch [1/30] | Batch 80 | Train Loss: 0.0931
# Epoch [1/30] | Batch 90 | Train Loss: 0.0912
# Epoch [1/30] | Batch 100 | Train Loss: 0.0969
# Epoch [2/30] | Batch 10 | Train Loss: 0.0992
# Epoch [2/30] | Batch 20 | Train Loss: 0.0954
# Epoch [2/30] | Batch 30 | Train Loss: 0.0960
# Epoch [2/30] | Batch 40 | Train Loss: 0.1046
# Epoch [2/30] | Batch 50 | Train Loss: 0.0938
# Epoch [2/30] | Batch 60 | Train Loss: 0.1008
# Epoch [2/30] | Batch 70 | Train Loss: 0.0853
# Epoch [2/30] | Batch 80 | Train Loss: 0.0955
# Epoch [2/30] | Batch 90 | Train Loss: 0.0956
# Epoch [2/30] | Batch 100 | Train Loss: 0.0937
# Epoch [3/30] | Batch 10 | Train Loss: 0.0963
# Epoch [3/30] | Batch 20 | Train Loss: 0.0877
# Epoch [3/30] | Batch 30 | Train Loss: 0.0968
# Epoch [3/30] | Batch 40 | Train Loss: 0.0933
# Epoch [3/30] | Batch 50 | Train Loss: 0.0954
# Epoch [3/30] | Batch 60 | Train Loss: 0.0984
# Epoch [3/30] | Batch 70 | Train Loss: 0.0992
# Epoch [3/30] | Batch 80 | Train Loss: 0.1127
# Epoch [3/30] | Batch 90 | Train Loss: 0.0900
# Epoch [3/30] | Batch 100 | Train Loss: 0.0839
# Epoch [4/30] | Batch 10 | Train Loss: 0.1004
# Epoch [4/30] | Batch 20 | Train Loss: 0.0853
# Epoch [4/30] | Batch 30 | Train Loss: 0.0974
# Epoch [4/30] | Batch 40 | Train Loss: 0.0894
# Epoch [4/30] | Batch 50 | Train Loss: 0.0982
# Epoch [4/30] | Batch 60 | Train Loss: 0.0997
# Epoch [4/30] | Batch 70 | Train Loss: 0.1000
# Epoch [4/30] | Batch 80 | Train Loss: 0.0991
# Epoch [4/30] | Batch 90 | Train Loss: 0.0981
# Epoch [4/30] | Batch 100 | Train Loss: 0.1007
# Epoch [5/30] | Batch 10 | Train Loss: 0.1023
# Epoch [5/30] | Batch 20 | Train Loss: 0.0935
# Epoch [5/30] | Batch 30 | Train Loss: 0.0978
# Epoch [5/30] | Batch 40 | Train Loss: 0.0884
# Epoch [5/30] | Batch 50 | Train Loss: 0.0919
# Epoch [5/30] | Batch 60 | Train Loss: 0.0892
# Epoch [5/30] | Batch 70 | Train Loss: 0.0948
# Epoch [5/30] | Batch 80 | Train Loss: 0.0850
# Epoch [5/30] | Batch 90 | Train Loss: 0.0973
# Epoch [5/30] | Batch 100 | Train Loss: 0.0869
# Epoch [6/30] | Batch 10 | Train Loss: 0.0984
# Epoch [6/30] | Batch 20 | Train Loss: 0.0948
# Epoch [6/30] | Batch 30 | Train Loss: 0.0824
# Epoch [6/30] | Batch 40 | Train Loss: 0.0891
# Epoch [6/30] | Batch 50 | Train Loss: 0.0963
# Epoch [6/30] | Batch 60 | Train Loss: 0.0901
# Epoch [6/30] | Batch 70 | Train Loss: 0.1068
# Epoch [6/30] | Batch 80 | Train Loss: 0.0964
# Epoch [6/30] | Batch 90 | Train Loss: 0.0990
# Epoch [6/30] | Batch 100 | Train Loss: 0.0885
# Epoch [7/30] | Batch 10 | Train Loss: 0.0969
# Epoch [7/30] | Batch 20 | Train Loss: 0.0952
# Epoch [7/30] | Batch 30 | Train Loss: 0.0911
# Epoch [7/30] | Batch 40 | Train Loss: 0.0936
# Epoch [7/30] | Batch 50 | Train Loss: 0.1054
# Epoch [7/30] | Batch 60 | Train Loss: 0.0892
# Epoch [7/30] | Batch 70 | Train Loss: 0.0956
# Epoch [7/30] | Batch 80 | Train Loss: 0.0864
# Epoch [7/30] | Batch 90 | Train Loss: 0.0903
# Epoch [7/30] | Batch 100 | Train Loss: 0.0913
# Epoch [8/30] | Batch 10 | Train Loss: 0.0966
# Epoch [8/30] | Batch 20 | Train Loss: 0.1028
# Epoch [8/30] | Batch 30 | Train Loss: 0.0820
# Epoch [8/30] | Batch 40 | Train Loss: 0.0809
# Epoch [8/30] | Batch 50 | Train Loss: 0.0900
# Epoch [8/30] | Batch 60 | Train Loss: 0.0887
# Epoch [8/30] | Batch 70 | Train Loss: 0.1051
# Epoch [8/30] | Batch 80 | Train Loss: 0.0866
# Epoch [8/30] | Batch 90 | Train Loss: 0.0914
# Epoch [8/30] | Batch 100 | Train Loss: 0.1014
# Epoch [9/30] | Batch 10 | Train Loss: 0.0935
# Epoch [9/30] | Batch 20 | Train Loss: 0.1121
# Epoch [9/30] | Batch 30 | Train Loss: 0.0950
# Epoch [9/30] | Batch 40 | Train Loss: 0.0920
# Epoch [9/30] | Batch 50 | Train Loss: 0.0982
# Epoch [9/30] | Batch 60 | Train Loss: 0.0898
# Epoch [9/30] | Batch 70 | Train Loss: 0.0890
# Epoch [9/30] | Batch 80 | Train Loss: 0.0998
# Epoch [9/30] | Batch 90 | Train Loss: 0.0947
# Epoch [9/30] | Batch 100 | Train Loss: 0.0994
# Epoch [10/30] | Batch 10 | Train Loss: 0.0928
# Epoch [10/30] | Batch 20 | Train Loss: 0.0884
# Epoch [10/30] | Batch 30 | Train Loss: 0.0912
# Epoch [10/30] | Batch 40 | Train Loss: 0.0921
# Epoch [10/30] | Batch 50 | Train Loss: 0.0929
# Epoch [10/30] | Batch 60 | Train Loss: 0.0912
# Epoch [10/30] | Batch 70 | Train Loss: 0.0884
# Epoch [10/30] | Batch 80 | Train Loss: 0.0970
# Epoch [10/30] | Batch 90 | Train Loss: 0.1003
# Epoch [10/30] | Batch 100 | Train Loss: 0.0977
# Epoch [11/30] | Batch 10 | Train Loss: 0.0931
# Epoch [11/30] | Batch 20 | Train Loss: 0.0897
# Epoch [11/30] | Batch 30 | Train Loss: 0.0828
# Epoch [11/30] | Batch 40 | Train Loss: 0.0883
# Epoch [11/30] | Batch 50 | Train Loss: 0.0888
# Epoch [11/30] | Batch 60 | Train Loss: 0.0949
# Epoch [11/30] | Batch 70 | Train Loss: 0.0910
# Epoch [11/30] | Batch 80 | Train Loss: 0.1002
# Epoch [11/30] | Batch 90 | Train Loss: 0.0925
# Epoch [11/30] | Batch 100 | Train Loss: 0.0905
# Epoch [12/30] | Batch 10 | Train Loss: 0.0851
# Epoch [12/30] | Batch 20 | Train Loss: 0.0987
# Epoch [12/30] | Batch 30 | Train Loss: 0.0974
# Epoch [12/30] | Batch 40 | Train Loss: 0.0981
# Epoch [12/30] | Batch 50 | Train Loss: 0.0804
# Epoch [12/30] | Batch 60 | Train Loss: 0.0827
# Epoch [12/30] | Batch 70 | Train Loss: 0.0925
# Epoch [12/30] | Batch 80 | Train Loss: 0.0945
# Epoch [12/30] | Batch 90 | Train Loss: 0.0951
# Epoch [12/30] | Batch 100 | Train Loss: 0.0854
# Epoch [13/30] | Batch 10 | Train Loss: 0.0860
# Epoch [13/30] | Batch 20 | Train Loss: 0.0981
# Epoch [13/30] | Batch 30 | Train Loss: 0.0848
# Epoch [13/30] | Batch 40 | Train Loss: 0.0921
# Epoch [13/30] | Batch 50 | Train Loss: 0.0958
# Epoch [13/30] | Batch 60 | Train Loss: 0.0908
# Epoch [13/30] | Batch 70 | Train Loss: 0.0825
# Epoch [13/30] | Batch 80 | Train Loss: 0.0984
# Epoch [13/30] | Batch 90 | Train Loss: 0.0919
# Epoch [13/30] | Batch 100 | Train Loss: 0.0888
# Epoch [14/30] | Batch 10 | Train Loss: 0.0759
# Epoch [14/30] | Batch 20 | Train Loss: 0.0902
# Epoch [14/30] | Batch 30 | Train Loss: 0.0868
# Epoch [14/30] | Batch 40 | Train Loss: 0.0920
# Epoch [14/30] | Batch 50 | Train Loss: 0.0786
# Epoch [14/30] | Batch 60 | Train Loss: 0.0939
# Epoch [14/30] | Batch 70 | Train Loss: 0.1008
# Epoch [14/30] | Batch 80 | Train Loss: 0.0916
# Epoch [14/30] | Batch 90 | Train Loss: 0.0969
# Epoch [14/30] | Batch 100 | Train Loss: 0.0844
# Epoch [15/30] | Batch 10 | Train Loss: 0.0858
# Epoch [15/30] | Batch 20 | Train Loss: 0.0935
# Epoch [15/30] | Batch 30 | Train Loss: 0.0916
# Epoch [15/30] | Batch 40 | Train Loss: 0.0936
# Epoch [15/30] | Batch 50 | Train Loss: 0.0862
# Epoch [15/30] | Batch 60 | Train Loss: 0.1031
# Epoch [15/30] | Batch 70 | Train Loss: 0.0903
# Epoch [15/30] | Batch 80 | Train Loss: 0.0798
# Epoch [15/30] | Batch 90 | Train Loss: 0.1043
# Epoch [15/30] | Batch 100 | Train Loss: 0.0883
# Epoch [16/30] | Batch 10 | Train Loss: 0.0879
# Epoch [16/30] | Batch 20 | Train Loss: 0.0834
# Epoch [16/30] | Batch 30 | Train Loss: 0.1063
# Epoch [16/30] | Batch 40 | Train Loss: 0.0933
# Epoch [16/30] | Batch 50 | Train Loss: 0.0885
# Epoch [16/30] | Batch 60 | Train Loss: 0.0873
# Epoch [16/30] | Batch 70 | Train Loss: 0.0983
# Epoch [16/30] | Batch 80 | Train Loss: 0.0904
# Epoch [16/30] | Batch 90 | Train Loss: 0.0833
# Epoch [16/30] | Batch 100 | Train Loss: 0.0905
# Epoch [17/30] | Batch 10 | Train Loss: 0.0987
# Epoch [17/30] | Batch 20 | Train Loss: 0.0842
# Epoch [17/30] | Batch 30 | Train Loss: 0.0910
# Epoch [17/30] | Batch 40 | Train Loss: 0.0964
# Epoch [17/30] | Batch 50 | Train Loss: 0.0928
# Epoch [17/30] | Batch 60 | Train Loss: 0.0827
# Epoch [17/30] | Batch 70 | Train Loss: 0.0908
# Epoch [17/30] | Batch 80 | Train Loss: 0.1007
# Epoch [17/30] | Batch 90 | Train Loss: 0.0941
# Epoch [17/30] | Batch 100 | Train Loss: 0.0846
# Epoch [18/30] | Batch 10 | Train Loss: 0.1012
# Epoch [18/30] | Batch 20 | Train Loss: 0.0852
# Epoch [18/30] | Batch 30 | Train Loss: 0.0909
# Epoch [18/30] | Batch 40 | Train Loss: 0.0823
# Epoch [18/30] | Batch 50 | Train Loss: 0.1041
# Epoch [18/30] | Batch 60 | Train Loss: 0.0925
# Epoch [18/30] | Batch 70 | Train Loss: 0.0859
# Epoch [18/30] | Batch 80 | Train Loss: 0.0866
# Epoch [18/30] | Batch 90 | Train Loss: 0.0981
# Epoch [18/30] | Batch 100 | Train Loss: 0.0974
# Epoch [19/30] | Batch 10 | Train Loss: 0.0865
# Epoch [19/30] | Batch 20 | Train Loss: 0.0851
# Epoch [19/30] | Batch 30 | Train Loss: 0.0905
# Epoch [19/30] | Batch 40 | Train Loss: 0.0964
# Epoch [19/30] | Batch 50 | Train Loss: 0.0907
# Epoch [19/30] | Batch 60 | Train Loss: 0.0956
# Epoch [19/30] | Batch 70 | Train Loss: 0.0965
# Epoch [19/30] | Batch 80 | Train Loss: 0.0823
# Epoch [19/30] | Batch 90 | Train Loss: 0.0886
# Epoch [19/30] | Batch 100 | Train Loss: 0.1031
# Epoch [20/30] | Batch 10 | Train Loss: 0.0870
# Epoch [20/30] | Batch 20 | Train Loss: 0.0908
# Epoch [20/30] | Batch 30 | Train Loss: 0.0964
# Epoch [20/30] | Batch 40 | Train Loss: 0.0800
# Epoch [20/30] | Batch 50 | Train Loss: 0.0896
# Epoch [20/30] | Batch 60 | Train Loss: 0.0977
# Epoch [20/30] | Batch 70 | Train Loss: 0.0938
# Epoch [20/30] | Batch 80 | Train Loss: 0.0915
# Epoch [20/30] | Batch 90 | Train Loss: 0.0963
# Epoch [20/30] | Batch 100 | Train Loss: 0.0823
# Epoch [21/30] | Batch 10 | Train Loss: 0.0834
# Epoch [21/30] | Batch 20 | Train Loss: 0.0927
# Epoch [21/30] | Batch 30 | Train Loss: 0.0941
# Epoch [21/30] | Batch 40 | Train Loss: 0.0885
# Epoch [21/30] | Batch 50 | Train Loss: 0.0836
# Epoch [21/30] | Batch 60 | Train Loss: 0.0936
# Epoch [21/30] | Batch 70 | Train Loss: 0.0885
# Epoch [21/30] | Batch 80 | Train Loss: 0.0924
# Epoch [21/30] | Batch 90 | Train Loss: 0.0913
# Epoch [21/30] | Batch 100 | Train Loss: 0.0837
# Epoch [22/30] | Batch 10 | Train Loss: 0.0951
# Epoch [22/30] | Batch 20 | Train Loss: 0.0993
# Epoch [22/30] | Batch 30 | Train Loss: 0.0885
# Epoch [22/30] | Batch 40 | Train Loss: 0.1020
# Epoch [22/30] | Batch 50 | Train Loss: 0.0825
# Epoch [22/30] | Batch 60 | Train Loss: 0.0860
# Epoch [22/30] | Batch 70 | Train Loss: 0.0859
# Epoch [22/30] | Batch 80 | Train Loss: 0.0901
# Epoch [22/30] | Batch 90 | Train Loss: 0.0916
# Epoch [22/30] | Batch 100 | Train Loss: 0.1021
# Epoch [23/30] | Batch 10 | Train Loss: 0.0867
# Epoch [23/30] | Batch 20 | Train Loss: 0.0904
# Epoch [23/30] | Batch 30 | Train Loss: 0.0934
# Epoch [23/30] | Batch 40 | Train Loss: 0.0863
# Epoch [23/30] | Batch 50 | Train Loss: 0.0860
# Epoch [23/30] | Batch 60 | Train Loss: 0.0942
# Epoch [23/30] | Batch 70 | Train Loss: 0.0950
# Epoch [23/30] | Batch 80 | Train Loss: 0.0850
# Epoch [23/30] | Batch 90 | Train Loss: 0.0976
# Epoch [23/30] | Batch 100 | Train Loss: 0.0802
# Epoch [24/30] | Batch 10 | Train Loss: 0.1001
# Epoch [24/30] | Batch 20 | Train Loss: 0.0875
# Epoch [24/30] | Batch 30 | Train Loss: 0.0851
# Epoch [24/30] | Batch 40 | Train Loss: 0.0842
# Epoch [24/30] | Batch 50 | Train Loss: 0.0982
# Epoch [24/30] | Batch 60 | Train Loss: 0.0852
# Epoch [24/30] | Batch 70 | Train Loss: 0.1033
# Epoch [24/30] | Batch 80 | Train Loss: 0.0866
# Epoch [24/30] | Batch 90 | Train Loss: 0.0904
# Epoch [24/30] | Batch 100 | Train Loss: 0.0878
# Epoch [25/30] | Batch 10 | Train Loss: 0.0882
# Epoch [25/30] | Batch 20 | Train Loss: 0.0991
# Epoch [25/30] | Batch 30 | Train Loss: 0.0975
# Epoch [25/30] | Batch 40 | Train Loss: 0.0880
# Epoch [25/30] | Batch 50 | Train Loss: 0.0891
# Epoch [25/30] | Batch 60 | Train Loss: 0.0862
# Epoch [25/30] | Batch 70 | Train Loss: 0.0926
# Epoch [25/30] | Batch 80 | Train Loss: 0.0799
# Epoch [25/30] | Batch 90 | Train Loss: 0.0934
# Epoch [25/30] | Batch 100 | Train Loss: 0.0837
# Epoch [26/30] | Batch 10 | Train Loss: 0.0944
# Epoch [26/30] | Batch 20 | Train Loss: 0.0869
# Epoch [26/30] | Batch 30 | Train Loss: 0.0922
# Epoch [26/30] | Batch 40 | Train Loss: 0.0921
# Epoch [26/30] | Batch 50 | Train Loss: 0.0934
# Epoch [26/30] | Batch 60 | Train Loss: 0.0937
# Epoch [26/30] | Batch 70 | Train Loss: 0.0832
# Epoch [26/30] | Batch 80 | Train Loss: 0.0927
# Epoch [26/30] | Batch 90 | Train Loss: 0.0966
# Epoch [26/30] | Batch 100 | Train Loss: 0.0900
# Epoch [27/30] | Batch 10 | Train Loss: 0.0988
# Epoch [27/30] | Batch 20 | Train Loss: 0.0924
# Epoch [27/30] | Batch 30 | Train Loss: 0.0901
# Epoch [27/30] | Batch 40 | Train Loss: 0.0827
# Epoch [27/30] | Batch 50 | Train Loss: 0.0945
# Epoch [27/30] | Batch 60 | Train Loss: 0.0933
# Epoch [27/30] | Batch 70 | Train Loss: 0.0924
# Epoch [27/30] | Batch 80 | Train Loss: 0.0921
# Epoch [27/30] | Batch 90 | Train Loss: 0.0929
# Epoch [27/30] | Batch 100 | Train Loss: 0.0913
# Epoch [28/30] | Batch 10 | Train Loss: 0.0866
# Epoch [28/30] | Batch 20 | Train Loss: 0.0955
# Epoch [28/30] | Batch 30 | Train Loss: 0.0812
# Epoch [28/30] | Batch 40 | Train Loss: 0.0954
# Epoch [28/30] | Batch 50 | Train Loss: 0.1061
# Epoch [28/30] | Batch 60 | Train Loss: 0.0950
# Epoch [28/30] | Batch 70 | Train Loss: 0.0876
# Epoch [28/30] | Batch 80 | Train Loss: 0.0854
# Epoch [28/30] | Batch 90 | Train Loss: 0.0940
# Epoch [28/30] | Batch 100 | Train Loss: 0.0896
# Epoch [29/30] | Batch 10 | Train Loss: 0.1026
# Epoch [29/30] | Batch 20 | Train Loss: 0.1026
# Epoch [29/30] | Batch 30 | Train Loss: 0.0910
# Epoch [29/30] | Batch 40 | Train Loss: 0.0913
# Epoch [29/30] | Batch 50 | Train Loss: 0.0943
# Epoch [29/30] | Batch 60 | Train Loss: 0.0830
# Epoch [29/30] | Batch 70 | Train Loss: 0.0845
# Epoch [29/30] | Batch 80 | Train Loss: 0.0909
# Epoch [29/30] | Batch 90 | Train Loss: 0.0904
# Epoch [29/30] | Batch 100 | Train Loss: 0.0900
# Epoch [30/30] | Batch 10 | Train Loss: 0.0892
# Epoch [30/30] | Batch 20 | Train Loss: 0.0882
# Epoch [30/30] | Batch 30 | Train Loss: 0.0850
# Epoch [30/30] | Batch 40 | Train Loss: 0.0825
# Epoch [30/30] | Batch 50 | Train Loss: 0.0827
# Epoch [30/30] | Batch 60 | Train Loss: 0.0954
# Epoch [30/30] | Batch 70 | Train Loss: 0.0981
# Epoch [30/30] | Batch 80 | Train Loss: 0.0910
# Epoch [30/30] | Batch 90 | Train Loss: 0.0875
# Epoch [30/30] | Batch 100 | Train Loss: 0.0936
# Training Complete!

# %%
def plot_losses(train_losses):
    plt.figure(figsize=(10,5))
    plt.plot(train_losses, label="Train Loss", color='blue', linestyle='-')
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training Loss vs Epoch")
    plt.legend()
    plt.grid()
    plt.show()

plot_losses(training_losses)

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([16, 1, 224, 224])
# torch.Size([16, 68, 2])
# torch.Size([16, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_1.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: write your answer here (double click to edit this cell)

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: write your answer here

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: write your answer here

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.backbone.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 0

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[-0.12288869 -0.00882696  0.07306653 -0.09074673  0.01690775 -0.00675013
#    0.03854414]
#  [-0.078401   -0.00921245  0.10965627 -0.12753817  0.06144645  0.02216265
#   -0.08163552]
#  [ 0.09047059  0.13386807  0.03688658 -0.01643454  0.05697043 -0.062085
#   -0.09526569]
#  [-0.14411533  0.09917336  0.06506401  0.03407023  0.09528197 -0.10369355
#    0.08994192]
#  [-0.14740641 -0.09908167  0.01833489  0.06064466  0.08776793  0.06545681
#    0.1383618 ]
#  [-0.12345366 -0.02270218 -0.12379792  0.05330956  0.04797035  0.1328054
#   -0.09264563]
#  [-0.08873397  0.04345053  0.06059723  0.06787455  0.13748124  0.08661892
#   -0.12924851]]
# (7, 7)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in its convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
## TODO: load in and display any image from the transformed test dataset
import cv2

test_img_idx= np.random.randint(0, len(test_dataset))   
test_img_tensor = test_dataset[test_img_idx]['image']
test_img= np.copy(test_img_tensor)
test_img=  np.squeeze(test_img)

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
filter_index= 9                   # Applying the filter index 15 on the test image
kernel= w[filter_index][0]  
# Filter an image to see the effect of a convolutional kernel
filter_test_img = cv2.filter2D(test_img, -1, kernel)


# Plot all the images
f, (ax_1, ax_2, ax_3) = plt.subplots(1, 3, figsize=(20,10))

ax_1.set_title("Original Test Image")
ax_1.imshow(test_img, cmap='gray')

ax_2.set_title("Filtered Test Image")
ax_2.imshow(filter_test_img, cmap='gray')

ax_3.set_title("Filter")
ax_3.imshow(kernel, cmap='gray')

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: (does it detect vertical lines or does it blur out noise, etc.) write your answer here

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
